# %%
from PIL import Image

infile = 'foto.jpg'

im = Image.open(infile)  
#im.show()
display (im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=209x246 at 0x14E62DB05B0>
# foto.jpg JPEG 209x246 RGB

# %%
out = im.resize((128,128))
display(out)
out = im.rotate(45) #degrees counter-clockwise
display(out)
out = im.transpose(Image.FLIP_LEFT_RIGHT)
display(out)
out = im.transpose(Image.FLIP_TOP_BOTTOM)
display(out)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x14E62DB0A90>
# <PIL.Image.Image image mode=RGB size=209x246 at 0x14E63E302B0>
# <PIL.Image.Image image mode=RGB size=209x246 at 0x14E63E30790>
# <PIL.Image.Image image mode=RGB size=209x246 at 0x14E63E302B0>

# %%
from PIL import Image, ImageFilter

out1 = im.filter(ImageFilter.BLUR)
display(out1)
out2 = im.filter(ImageFilter.GaussianBlur(radius=20))
display(out2)
# Out:
# <PIL.Image.Image image mode=RGB size=209x246 at 0x14E63E25790>
# <PIL.Image.Image image mode=RGB size=209x246 at 0x14E64409700>
